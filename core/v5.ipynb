# %%
# %pip install tqdm

import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np

from v0.game import BullsNCows
from v0.tools import (
    guess_based_on_score,
    guess_based_on_entropy,
    guess_based_on_candidates,
)
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
digits, n_iter=2, 1000
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
secrets = [random.choice(game.originals) for _ in range(n_iter)]

# %%
plt.subplot(2, 2, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_1 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_1)/len(scores_1):.2f}')
plt.hist(scores_1, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(2, 2, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_2 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_2)/len(scores_2):.2f}')
plt.hist(scores_2, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(2, 2, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_3 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_3)/len(scores_3):.2f}')
plt.hist(scores_3, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(2, 2, 4)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_4 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_4)/len(scores_4):.2f}')
plt.hist(scores_4, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.tight_layout()
plt.show()
# Out:
# ...
# 100%|██████████| 400/400 [00:03<00:00, 100.44it/s]

# %%
n_iter = 400

plt.subplot(3, 2, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_1 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.log2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_log2 ({digits}) - {sum(scores_1)/len(scores_1):.2f}')
plt.hist(scores_1, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_2 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_sqrt ({digits}) - {sum(scores_2)/len(scores_2):.2f}')
plt.hist(scores_2, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_3 = [game.reset().play(secret=secrets[i], calc_entropy_score=lambda x : x)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_3)/len(scores_3):.2f}')
plt.hist(scores_3, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 4)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_4 = [game.reset().play(secret=secrets[i], calc_entropy_score=lambda x : x*2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_2x ({digits}) - {sum(scores_4)/len(scores_4):.2f}')
plt.hist(scores_4, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 5)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_5 = [game.reset().play(secret=secrets[i], calc_entropy_score=lambda x : x**2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score^2 ({digits}) - {sum(scores_5)/len(scores_5):.2f}')
plt.hist(scores_5, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 6)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_6 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.exp2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_exp2 ({digits}) - {sum(scores_6)/len(scores_6):.2f}')
plt.hist(scores_6, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.tight_layout()
plt.show()
# Out:
# ...
# 100%|██████████| 400/400 [00:04<00:00, 91.22it/s]

# %%
n_iter = 800

plt.subplot(3, 2, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_1 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.log2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_log2 ({digits}) - {sum(scores_1)/len(scores_1):.2f}')
plt.hist(scores_1, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_2 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_sqrt ({digits}) - {sum(scores_2)/len(scores_2):.2f}')
plt.hist(scores_2, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_3 = [game.reset().play(secret=secrets[i], calc_entropy_score=lambda x : x)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_3)/len(scores_3):.2f}')
plt.hist(scores_3, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 4)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_4 = [game.reset().play(secret=secrets[i], calc_entropy_score=lambda x : x*2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_2x ({digits}) - {sum(scores_4)/len(scores_4):.2f}')
plt.hist(scores_4, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 5)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_5 = [game.reset().play(secret=secrets[i], calc_entropy_score=lambda x : x**2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score^2 ({digits}) - {sum(scores_5)/len(scores_5):.2f}')
plt.hist(scores_5, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(3, 2, 6)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_6 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.exp2)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score_exp2 ({digits}) - {sum(scores_6)/len(scores_6):.2f}')
plt.hist(scores_6, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.tight_layout()
plt.show()

# %%
plt.subplot(2, 2, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_1 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_1)/len(scores_1):.2f}')
plt.hist(scores_1, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(2, 2, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores_2 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_score ({digits}) - {sum(scores_2)/len(scores_2):.2f}')
plt.hist(scores_2, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(2, 2, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_entropy, verbose=False)
scores_3 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_entropy ({digits}) - {sum(scores_3)/len(scores_3):.2f}')
plt.hist(scores_3, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(2, 2, 4)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_candidates, verbose=False)
scores_4 = [game.reset().play(secret=secrets[i], calc_entropy_score=np.sqrt)[0] for i in tqdm(range(n_iter))]
plt.ylim(0, n_iter*2//3)
plt.title(f'guess_based_on_candidates ({digits}) - {sum(scores_4)/len(scores_4):.2f}')
plt.hist(scores_4, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.tight_layout()
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:01<00:00, 70.84it/s]

# %%
digits, n_iter=2, 200

plt.subplot(1, 3, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Score ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(1, 3, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_entropy, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Entropy ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(1, 3, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_candidates, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Candidates ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.tight_layout()
plt.show()
# Out:
# ...
# 100%|██████████| 200/200 [00:03<00:00, 55.60it/s]

# %%
digits, n_iter=3, 100

plt.subplot(1, 3, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Score ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(1, 3, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_entropy, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Entropy ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(1, 3, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_candidates, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Candidates ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.tight_layout()
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:22<00:00,  4.51it/s]

# %%
digits, n_iter=4, 100

plt.subplot(1, 3, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Score ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(1, 3, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_entropy, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Entropy ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.subplot(1, 3, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_candidates, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
plt.ylim(0, n_iter)
plt.title(f'Candidates ({digits}) - {sum(scores)/len(scores):.2f}')
plt.hist(scores, bins=np.arange(0, 10), align='left', edgecolor='black', linewidth=0.4)

plt.tight_layout()
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [12:22<00:00,  7.43s/it]

# %%
# %pip install tqdm
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np

from v0.game import BullsNCows
from v0.tools import (
    guess_based_on_score,
    guess_based_on_entropy,
    guess_based_on_candidates,
)

# %%
digits, n_iter=2, 100

plt.subplot(1, 3, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
# plt.title(f'Score-based {digits} Digits - {n_iter} Iterations - {sum(scores) / len(scores)}')
plt.title(f'Score-based ({digits})')
plt.hist(scores, bins=np.arange(0, max(scores)+1), align='left')

plt.subplot(1, 3, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_entropy, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
# plt.title(f'Entropy-based {digits} Digits - {n_iter} Iterations - {sum(scores) / len(scores)}')
plt.title(f'Entropy-based ({digits})')
plt.hist(scores, bins=np.arange(0, max(scores)+1), align='left')

plt.subplot(1, 3, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_candidates, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
# plt.title(f'Candidates-based {digits} Digits - {n_iter} Iterations - {sum(scores) / len(scores)}')
plt.title(f'Candidate-based ({digits})')
plt.hist(scores, bins=np.arange(0, max(scores)+1), align='left')

plt.tight_layout()
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:01<00:00, 76.31it/s]

# %%
digits, n_iter=3, 100

plt.subplot(1, 3, 1)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_score, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
# plt.title(f'Score-based {digits} Digits - {n_iter} Iterations - {sum(scores) / len(scores)}')
plt.title(f'Score-based ({digits})')
plt.hist(scores, bins=np.arange(0, max(scores)+1), align='left')

plt.subplot(1, 3, 2)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_entropy, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
# plt.title(f'Entropy-based {digits} Digits - {n_iter} Iterations - {sum(scores) / len(scores)}')
plt.title(f'Entropy-based ({digits})')
plt.hist(scores, bins=np.arange(0, max(scores)+1), align='left')

plt.subplot(1, 3, 3)
game = BullsNCows(digits=digits, guess_algorithm=guess_based_on_candidates, verbose=False)
scores = [game.reset().play()[0] for _ in tqdm(range(n_iter))]
# plt.title(f'Candidates-based {digits} Digits - {n_iter} Iterations - {sum(scores) / len(scores)}')
plt.title(f'Candidate-based ({digits})')
plt.hist(scores, bins=np.arange(0, max(scores)+1), align='left')

plt.tight_layout()
plt.show()
# Out:
# ...
#  88%|████████▊ | 88/100 [00:26<00:04,  2.57it/s]
